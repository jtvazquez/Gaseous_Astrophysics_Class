# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt

# %%
fname = 'galex_1615759171.csv'
fname = 'galex_1656405718.csv'
fname = 'galex_1663445000.csv'
fname = 'galex_1663685125.csv'
fname = 'galex_1664282156.csv'
#fname = 'galex_1665227687.csv'
fname = 'galex_1699521765.csv'
fname ='galex_1699646656.csv'
fname = 'galex_1699827890.csv'
dframe = pd.read_csv(fname)
dframe['ra'][826],dframe['dec'][826]
# Out:
# (11.737544938457198, 40.9668674324432)

# %%
fuv_mags = dframe['fuv_mag'].to_numpy()
fuv_og = fuv_mags

# %%
nanmask = fuv_mags != -999.
fuv_mags = fuv_mags[nanmask]

# %%
fuv_min = np.min(fuv_mags)
fuv_sorted = np.sort(fuv_mags)
fuv_sorted
# Out:
# array([19.60818, 19.62291, 19.71475, 20.52458, 20.54507, 20.54827,
#        20.65925, 20.69086, 20.70059, 20.70703, 20.76739, 20.92013,
#        20.97291, 20.97684, 21.04615, 21.05361, 21.09492, 21.10793,
#        21.2267 , 21.23287, 21.24626, 21.32124, 21.46334, 21.52139,
#        21.60124, 21.68847, 21.70202, 21.72562, 21.76763, 21.79933,
#        21.8148 , 21.87404, 21.90741, 21.93055, 21.94967, 21.963  ,
#        22.00298, 22.01031, 22.034  , 22.04478, 22.05185, 22.09696,
#        22.10556, 22.12337, 22.12653, 22.14004, 22.15822, 22.20989,
#        22.21824, 22.21912, 22.23773, 22.24125, 22.27165, 22.28039,
#        22.28307, 22.28799, 22.30331, 22.30725, 22.32655, 22.34464,
#        22.36887, 22.36995, 22.37949, 22.38303, 22.39205, 22.40857,
#        22.41764, 22.4243 , 22.43579, 22.4384 , 22.44688, 22.44876,
#        22.45465, 22.4641 , 22.50398, 22.51656, 22.52291, 22.52575,
#        22.53314, 22.55429, 22.56282, 22.56675, 22.57728, 22.58211,
# ...

# %%
10**1.8
# Out:
# 63.09573444801933

# %%
#np.where(fuv_og == fuv_min)[0][0]
np.where(fuv_og == 19.71475)[0][0]
#np.where(fuv_og == fuv_min)[0][0]
# Out:
# 826

# %%
np.sort(fuv_mags)
# Out:
# array([17.8314 , 17.8347 , 17.86105, 17.86353, 17.89295, 17.89465,
#        17.90405, 17.96554, 18.05104, 20.33505, 20.44357, 20.44678,
#        20.47067, 20.50184, 20.51472, 20.55904, 20.56322, 20.5752 ,
#        20.64808, 20.65984, 20.68683, 20.78279, 20.81898, 20.83665,
#        20.84604, 20.85739, 20.91381, 20.92355, 20.92822, 20.93282,
#        20.94543, 20.97308, 20.98014, 21.01445, 21.02052, 21.0253 ,
#        21.34978, 21.41821, 21.46728, 21.4969 , 21.53771, 21.55629,
#        21.69263, 21.71353, 21.75534, 21.79129, 21.80433, 21.8567 ,
#        21.91434, 21.9166 , 21.93492, 21.94152, 21.97778, 22.00063,
#        22.00253, 22.0351 , 22.03797, 22.04149, 22.04741, 22.05004,
#        22.06524, 22.08411, 22.10238, 22.11318, 22.13049, 22.17095,
#        22.17294, 22.19058, 22.19128, 22.19553, 22.19868, 22.21921,
#        22.22615, 22.27256, 22.27269, 22.27596, 22.27736, 22.30264,
#        22.30273, 22.30854, 22.30895, 22.32852, 22.33724, 22.36822,
# ...

# %%
dframe['nuv_mag'].to_numpy()[84]
# Out:
# 22.46288
